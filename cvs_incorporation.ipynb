# %%
# Add dependencies
import glob
import pandas as pd

# %%
# glob.glob('data*.csv') - returns List[str]
# pd.read_csv(f) - returns pd.DataFrame()
# for f in glob.glob() - returns a List[DataFrames]
# pd.concat() - returns one pd.DataFrame()
data_2019 = pd.concat([pd.read_csv(f) for f in glob.glob('2019/*.csv')], ignore_index = True)
data_march = pd.concat([pd.read_csv(f) for f in glob.glob('march/*.csv')], ignore_index = True)
# Out:
# /Users/yoo/opt/anaconda2/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
clean_data_ridership.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
clean_data_ridership.count()
# Out:
# tripduration               422666
# starttime                  422666
# stoptime                   422666
# start station id           422666
# start station name         422666
# start station latitude     422666
# start station longitude    422666
# end station id             422666
# end station name           422666
# end station latitude       422666
# end station longitude      422666
# bikeid                     422666
# usertype                   422666
# birth year                 422666
# gender                     422666
# dtype: int64

# %%
clean_data_trip.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0      NaN         NaN             NaN                   NaN
# 1      NaN         NaN             NaN                   NaN
# 2      NaN         NaN             NaN                   NaN
# 3      NaN         NaN             NaN                   NaN
# 4      NaN         NaN             NaN                   NaN
#
#    End Station Longitude End Station Name  Gender  Start Station ID  \
# 0                    NaN              NaN     NaN               NaN
# 1                    NaN              NaN     NaN               NaN
# 2                    NaN              NaN     NaN               NaN
# 3                    NaN              NaN     NaN               NaN
# 4                    NaN              NaN     NaN               NaN
#
#    Start Station Latitude  Start Station Longitude  ... end station name  \
# 0                     NaN                      NaN  ...     Newport PATH
# ...

# %%
clean_data_trip.count()
# Out:
# Bike ID                    25712
# Birth Year                 24318
# End Station ID             25712
# End Station Latitude       25712
# End Station Longitude      25712
# End Station Name           25712
# Gender                     25712
# Start Station ID           25712
# Start Station Latitude     25712
# Start Station Longitude    25712
# Start Station Name         25712
# Start Time                 25712
# Stop Time                  25712
# Trip Duration              25712
# User Type                  25667
# bikeid                     40715
# birth year                 40715
# end station id             40715
# end station latitude       40715
# end station longitude      40715
# end station name           40715
# gender                     40715
# start station id           40715
# start station latitude     40715
# start station longitude    40715
# start station name         40715
# starttime                  40715
# stoptime                   40715
# ...

# %%
data_2019.to_csv("data_2019.csv")
data_march.to_csv("data_march.csv")
